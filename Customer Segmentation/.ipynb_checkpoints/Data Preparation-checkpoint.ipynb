# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import pickle
import os
import itertools
import datetime
import random
import missingno as msno
import numpy as np
import pandas as pd
from pandas import DataFrame

import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
pd.set_option('max_columns', 1000)

# %%
SAVE_PROCESSED_DATA = True

# %%
scriptDir = os.getcwd()
relPath = r"../Customer Segmentation/"
sampleFilePath1 = os.path.join(scriptDir, relPath, 'CJ Bookings.xlsx')
sampleFilePath2 = os.path.join(scriptDir, relPath, 'CJ GP.xlsx')
relPathOutput = r"../output/"
outputFolderPath = os.path.join(scriptDir, relPathOutput)

# %%
df1 = pd.read_excel(sampleFilePath1, header=0, encoding='latin1')
df2 = pd.read_excel(sampleFilePath2, header=0, encoding='latin1')
print('Dataframe dimensions:', df1.shape)
print('Dataframe dimensions:', df2.shape)
# Out:
# Dataframe dimensions: (15432, 21)
# Dataframe dimensions: (11308, 5)

# %% [markdown]
# # Data Observation
# - Merge two sheet by the 'RawLabel'

# %%
df3 = pd.merge(df1, df2, on=['Accountid', 'ownerid', 'enqid'], how='outer')

# %% [markdown]
# |Variable Name: | Variable Description: |
# |-- |-- |
# |**enqid** | Nominal, a integral number uniquely assiged to ??? ignore |
# |**contactid** | Nominal, a integral number uniquely assiged to each order |
# |**ownerid** | Nominal,  a integral number uniquely assiged to each distinct operator |
# |**companyid** | Nominal,  a integral number uniquely assiged to each distinct company|
# |**Industry** | Nomial|
# |**Office Country Code** | Nomial, Same as Fiscal|
# |**booked date** | Numerical, the day and time when each order was booked|
# |**creation date** | Numerical, the day and time when each order was confirmed |
# |**Flight date** | Numerical, the day and time when AP received the money|
# |**Flight Year** | Numerical|
# |**Route Code**| Nomial, the route for each transaction|
# |**Aircraft code**| Nomial, type of aircraft|
# |**no of sectors**| Numerical, transit time|
# |**passengers** | Numerical, number of passengier|
# |**Total Flight Time(Dec)** | Numerical, length of each flight|
# |**Total Distance (NMi)** | Numerical, distance for the trip|
# |**gross** | Numerical|
# |**Gross Margin** | categorical|

# %% [markdown]
# **Which features are categorical?**
# - Categorical: Office country code, Job status, industrycode, aircraftcode, routecode
#
# **Which are time features?**
# - Time feature: booked date, creation date, Flight date, Flight Year
#
# **Which features are numerical?**
# - Numerical: no of sectors, passengers, Total Flight Time, Total Distance, gross, cost, Gross Margin

# %%
df3.head()
# Out:
#    Accountid  ownerid  enqid   Flight ID Fiscal   scode         Job Status  \
# 0         57       18   1098   EN2269092  ITSET  CLEGRO             Closed
# 1        195       60    571   EN2243572  FRSET  TELFAS             Closed
# 2        213       43    116  EN21635911  DESET  MHERTH  Cancelled Enquiry
# 3        213       43    116  EN21635933  DESET  MHERTH  Cancelled Enquiry
# 4       1969       44   1080   EN2268302  UKSET   MHOLT           Invoiced
#
#   industrycode                        Industry Office Country Code  \
# 0         GOVT  Government Ministries & Agenci                  IT
# 1         TOUR                  Tour Operators                  FR
# 2          NaN                         Unknown             unknown
# 3          NaN                         Unknown             unknown
# 4        SPORT  Sports Teams & Tour Organisers                  UK
#
#       Product Flight date  Flight Year               Route code  \
# 0  CJ - Adhoc  2017-01-01         2017  ZAG/FCO/LMP/PMO/NBE/FCO
# 1    Tour Ops  2017-01-01         2017  CDG/FUE/TLS/NTE/FUE/CDG
# 2  CJ - Adhoc  2017-01-01         2017              MUC/RIX/MUC
# 3  CJ - Adhoc  2017-01-01         2017              MUC/RIX/MUC
# 4  CJ - Adhoc  2017-01-01         2017              SOU/LPL/SOU
#
#        Aircraft code  no of sectors  passengers  Total Flight Time (Dec)  \
# 0              FK100              5         109                     4.24
# 1           A320-200              5         180                    14.51
# 2  B747-300,B757-200              2         395                     3.50
# 3  B747-300,B757-200              2         202                     3.84
# 4           B733-VIP              2          60                     1.84
#
#    Total Distance (NMi)  margin_x data_x     margin_y data_y
# 0               1075.07       0.0   axis  2615.661430   axis
# 1               5570.62       0.0   axis  1752.491975   axis
# 2               1354.40       0.0   axis     0.000000   axis
# 3               1354.40       0.0   axis     0.000000   axis
# 4                308.30       0.0   axis  1786.800000   axis

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15447 entries, 0 to 15446
# Data columns (total 23 columns):
# Accountid                  15447 non-null int64
# ownerid                    15447 non-null int64
# enqid                      15447 non-null int64
# Flight ID                  15138 non-null object
# Fiscal                     15447 non-null object
# scode                      15447 non-null object
# Job Status                 15447 non-null object
# industrycode               12576 non-null object
# Industry                   15138 non-null object
# Office Country Code        15447 non-null object
# Product                    15447 non-null object
# Flight date                15447 non-null datetime64[ns]
# Flight Year                15447 non-null int64
# Route code                 15134 non-null object
# Aircraft code              11898 non-null object
# no of sectors              15447 non-null int64
# passengers                 15447 non-null int64
# Total Flight Time (Dec)    15447 non-null float64
# Total Distance (NMi)       15447 non-null float64
# margin_x                   15447 non-null float64
# data_x                     15447 non-null object
# margin_y                   15446 non-null float64
# data_y                     15447 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(6), object(12)
# memory usage: 2.8+ MB

# %% [markdown]
# **Which features contain blank, null or empty values?**
# - Aircraft code > Route code contain a number of null values
# - passengers contains a number of 0 values

# %% [markdown]
# ## Data Cleaning
# - Filter the data for CJ department

# %%
df3 = df3[(df3['Product'] != 'Tour Ops')]
df3.drop(['margin_x', 'data_x', 'data_y'], axis=1)
# Out:
#        Accountid  ownerid  enqid   Flight ID Fiscal   scode  \
# 0             57       18   1098   EN2269092  ITSET  CLEGRO
# 2            213       43    116  EN21635911  DESET  MHERTH
# 3            213       43    116  EN21635933  DESET  MHERTH
# 4           1969       44   1080   EN2268302  UKSET   MHOLT
# 6           2031       31    581   EN2244091  UKSET  JCAVAL
# 7           2031       31    581   EN2244092  UKSET  JCAVAL
# 8           2051       29    966   EN2264791  DESET  IMUTLU
# 9           2051       29    966   EN2264792  DESET  IMUTLU
# 10          2104       29     52   EN2134291  DESET  IMUTLU
# 11          2104       29     53   EN2134331  DESET  IMUTLU
# 12          2104       29     54   EN2134351  DESET  IMUTLU
# 13          2104       29     55   EN2134371  DESET  IMUTLU
# 14          2104       29     56   EN2134421  DESET  IMUTLU
# 15          2104       29     57   EN2134431  DESET  IMUTLU
# 16          2104       29     58   EN2134451  DESET  IMUTLU
# 17          2120       29     13   EN2043901  DESET  IMUTLU
# 18           376       43   1069   EN2267572  DESET  MHERTH
# 19           376       43   1069   EN2267577  DESET  MHERTH
# 22          1234       11    799   EN2256163  ATSET  BEGGER
# 23          1856       12    162   EN2182251  FRSET  CBOUGE
# 24          2104       29     47   EN2129294  DESET  IMUTLU
# 25           108       29    790   EN2255694  DESET  IMUTLU
# 26           263       34   2709   EN2312211  FRSET  KRIGHI
# 27          1159       32    117   EN2164942  USSET  JSILVA
# 28          1159       59     49   EN2129671  USSET  SMOORE
# 29          1159       32    377   EN2228122  USSET  JSILVA
# 30          1159       32    377   EN2228125  USSET  JSILVA
# 31          1159       32    377   EN2228126  USSET  JSILVA
# 32          1159       32    964   EN2264752  USSET  JSILVA
# 33          1159       32    964   EN2264753  USSET  JSILVA
# ...          ...      ...    ...         ...    ...     ...
# 15407        861       30  10846   EN2682612  DESET  IOTTER
# 15408        861       30  10846   EN2682613  DESET  IOTTER
# 15409       1569       12  10414   EN2662771  FRSET  CBOUGE
# 15410       2125       12  10936   EN2690501  FRSET  CBOUGE
# 15411       1081       12  10972   EN2692701  FRSET  CBOUGE
# 15412       1427       12   8986   EN2609451  FRSET  CBOUGE
# 15413       1695       53  10292   EN2655982  DESET  SDROBJ
# 15414       1522       41   9166  EN26176324  ATSET  MCERNA
# 15415       1522       41   9166  EN26176325  ATSET  MCERNA
# 15416       1522       41   9166  EN26176329  ATSET  MCERNA
# 15417       1522       41   9166  EN26176337  ATSET  MCERNA
# 15418       1522       41   9166  EN26176350  ATSET  MCERNA
# 15419       1543       12  10398   EN2662251  FRSET  CBOUGE
# 15420         93       41  10169  EN26464923  ATSET  MCERNA
# 15421         93       41  10169   EN2646494  ATSET  MCERNA
# 15422       1931       11  10314   EN2657662  ATSET  BEGGER
# 15423        599       16   9172   EN2618082  DESET  CJUDIC
# 15424        972       41   9024  EN26110434  ATSET  MCERNA
# 15425        972       41   9024  EN26110437  ATSET  MCERNA
# 15427       1889        9  11010   EN2695011  DESET  ASEYLE
# 15428       1889        9  11010   EN2695012  DESET  ASEYLE
# 15429       1466       12   9587   EN2633811  FRSET  CBOUGE
# 15435       1912       61  10154  EN26456430  ATSET  UNEKRA
# 15439       2121       12   8746   EN2596141  FRSET  CBOUGE
# 15441       1692       30  11013   EN2695152  DESET  IOTTER
# 15442       1692       30  11013   EN2695153  DESET  IOTTER
# 15443       1171       12  10914   EN2689621  FRSET  CBOUGE
# 15444       1070       30  10862   EN2684972  DESET  IOTTER
# 15445       1070       30  10862   EN2684973  DESET  IOTTER
# 15446       1235       46   3105   EN2323766  ATSET  MTRULL
#
#               Job Status industrycode                        Industry  \
# 0                 Closed         GOVT  Government Ministries & Agenci
# 2      Cancelled Enquiry          NaN                         Unknown
# 3      Cancelled Enquiry          NaN                         Unknown
# 4               Invoiced        SPORT  Sports Teams & Tour Organisers
# 6      Cancelled Enquiry         MGMT          Managment Company P-91
# 7      Cancelled Enquiry         MGMT          Managment Company P-91
# 8      Cancelled Enquiry      MEDICAL  Medevac, Hospitals, Ambulances
# 9      Cancelled Enquiry      MEDICAL  Medevac, Hospitals, Ambulances
# 10     Cancelled Enquiry          CAR        Car / Motor-related Co s
# 11     Cancelled Enquiry          CAR        Car / Motor-related Co s
# 12     Cancelled Enquiry          CAR        Car / Motor-related Co s
# 13     Cancelled Enquiry          CAR        Car / Motor-related Co s
# 14     Cancelled Enquiry          CAR        Car / Motor-related Co s
# 15     Cancelled Enquiry          CAR        Car / Motor-related Co s
# 16     Cancelled Enquiry          CAR        Car / Motor-related Co s
# 17     Cancelled Enquiry          CAR        Car / Motor-related Co s
# 18     Cancelled Enquiry          NaN                         Unknown
# 19     Cancelled Enquiry          NaN                         Unknown
# 22              Invoiced         GOVT  Government Ministries & Agenci
# 23     Cancelled Enquiry         TRAV                   Travel Agents
# 24                Closed          CAR        Car / Motor-related Co s
# 25                Closed          NaN                         Unknown
# 26               Enquiry         CONF      Conference, Incentive, etc
# 27     Cancelled Enquiry     OPERATOR               Aircraft Operator
# 28     Cancelled Enquiry     OPERATOR               Aircraft Operator
# 29                Closed     OPERATOR               Aircraft Operator
# 30                Closed     OPERATOR               Aircraft Operator
# 31                Closed     OPERATOR               Aircraft Operator
# 32                Closed     OPERATOR               Aircraft Operator
# 33                Closed     OPERATOR               Aircraft Operator
# ...                  ...          ...                             ...
# 15407            Enquiry          NaN                         Unknown
# 15408            Enquiry          NaN                         Unknown
# 15409            Enquiry         CONF      Conference, Incentive, etc
# 15410            Enquiry          NaN                         Unknown
# 15411            Enquiry          NaN                         Unknown
# 15412            Enquiry          NaN                         Unknown
# 15413            Enquiry          NaN                         Unknown
# 15414            Enquiry         CONF      Conference, Incentive, etc
# 15415            Enquiry         CONF      Conference, Incentive, etc
# 15416            Enquiry         CONF      Conference, Incentive, etc
# 15417            Enquiry         CONF      Conference, Incentive, etc
# 15418            Enquiry         CONF      Conference, Incentive, etc
# 15419            Enquiry    UTILITIES    Water Gas Electric Phone etc
# 15420  Cancelled Enquiry         TOUR                  Tour Operators
# 15421  Cancelled Enquiry         TOUR                  Tour Operators
# 15422            Enquiry         TOUR                  Tour Operators
# 15423            Enquiry          NaN                         Unknown
# 15424  Cancelled Enquiry          NaN                         Unknown
# 15425  Cancelled Enquiry          NaN                         Unknown
# 15427            Enquiry         CONF      Conference, Incentive, etc
# 15428            Enquiry         CONF      Conference, Incentive, etc
# 15429            Enquiry         CONF      Conference, Incentive, etc
# 15435            Enquiry         TRAV                   Travel Agents
# 15439            Enquiry         TRAV                   Travel Agents
# 15441            Enquiry         CONF      Conference, Incentive, etc
# 15442            Enquiry         CONF      Conference, Incentive, etc
# 15443            Enquiry          NaN                         Unknown
# 15444            Enquiry          NaN                         Unknown
# 15445            Enquiry          NaN                         Unknown
# 15446             Closed         GOVT  Government Ministries & Agenci
#
#       Office Country Code     Product Flight date  Flight Year  \
# 0                      IT  CJ - Adhoc  2017-01-01         2017
# 2                 unknown  CJ - Adhoc  2017-01-01         2017
# 3                 unknown  CJ - Adhoc  2017-01-01         2017
# 4                      UK  CJ - Adhoc  2017-01-01         2017
# 6                      UK  CJ - Adhoc  2017-01-01         2017
# 7                      UK  CJ - Adhoc  2017-01-01         2017
# 8                      DE  CJ - Adhoc  2017-01-01         2017
# 9                      DE  CJ - Adhoc  2017-01-01         2017
# 10                     DE  CJ - Adhoc  2017-01-01         2017
# 11                     DE  CJ - Adhoc  2017-01-01         2017
# 12                     DE  CJ - Adhoc  2017-01-01         2017
# 13                     DE  CJ - Adhoc  2017-01-01         2017
# 14                     DE  CJ - Adhoc  2017-01-01         2017
# 15                     DE  CJ - Adhoc  2017-01-01         2017
# 16                     DE  CJ - Adhoc  2017-01-01         2017
# 17                     DE  CJ - Adhoc  2017-01-01         2017
# 18                unknown  CJ - Adhoc  2017-01-02         2017
# 19                unknown  CJ - Adhoc  2017-01-02         2017
# 22                     AT  CJ - Adhoc  2017-01-03         2017
# 23                     FR  CJ - Adhoc  2017-01-03         2017
# 24                     DE  CJ - Adhoc  2017-01-03         2017
# 25                unknown  CJ - Adhoc  2017-01-04         2017
# 26                     FR  CJ - Adhoc  2017-01-04         2017
# 27                     AT  CJ - Adhoc  2017-01-04         2017
# 28                     AT  CJ - Adhoc  2017-01-04         2017
# 29                     AT  CJ - Adhoc  2017-01-04         2017
# 30                     AT  CJ - Adhoc  2017-01-04         2017
# 31                     AT  CJ - Adhoc  2017-01-04         2017
# 32                     AT  CJ - Adhoc  2017-01-04         2017
# 33                     AT  CJ - Adhoc  2017-01-04         2017
# ...                   ...         ...         ...          ...
# 15407             unknown  CJ - Adhoc  2020-10-01         2020
# 15408             unknown  CJ - Adhoc  2020-10-01         2020
# 15409                  FR  CJ - Adhoc  2020-10-01         2020
# 15410             unknown  CJ - Adhoc  2020-10-01         2020
# 15411             unknown  CJ - Adhoc  2020-10-04         2020
# 15412             unknown  CJ - Adhoc  2020-10-09         2020
# 15413             unknown  CJ - Adhoc  2020-10-17         2020
# 15414                  AT  CJ - Adhoc  2020-10-19         2020
# 15415                  AT  CJ - Adhoc  2020-10-19         2020
# 15416                  AT  CJ - Adhoc  2020-10-19         2020
# 15417                  AT  CJ - Adhoc  2020-10-19         2020
# 15418                  AT  CJ - Adhoc  2020-10-19         2020
# 15419                  MC  CJ - Adhoc  2020-10-21         2020
# 15420                  AT  CJ - Adhoc  2020-10-23         2020
# 15421                  AT  CJ - Adhoc  2020-10-23         2020
# 15422                  AT  CJ - Adhoc  2020-10-23         2020
# 15423             unknown  CJ - Adhoc  2020-10-26         2020
# 15424             unknown  CJ - Adhoc  2020-11-01         2020
# 15425             unknown  CJ - Adhoc  2020-11-01         2020
# 15427                  DE  CJ - Adhoc  2020-12-04         2020
# 15428                  DE  CJ - Adhoc  2020-12-04         2020
# 15429                  FR  CJ - Adhoc  2020-12-06         2020
# 15435                  AT  CJ - Adhoc  2021-02-22         2021
# 15439                  FR  CJ - Adhoc  2021-04-01         2021
# 15441                  DE  CJ - Adhoc  2021-04-21         2021
# 15442                  DE  CJ - Adhoc  2021-04-21         2021
# 15443             unknown  CJ - Adhoc  2021-05-01         2021
# 15444             unknown  CJ - Adhoc  2021-05-09         2021
# 15445             unknown  CJ - Adhoc  2021-05-09         2021
# 15446                  AT  CJ - Adhoc  2029-07-03         2029
#
#                             Route code                Aircraft code  \
# 0              ZAG/FCO/LMP/PMO/NBE/FCO                        FK100
# 2                          MUC/RIX/MUC            B747-300,B757-200
# 3                          MUC/RIX/MUC            B747-300,B757-200
# 4                          SOU/LPL/SOU                     B733-VIP
# 6                          EMA/MME/EMA                    E145,E170
# 7                          EMA/MME/EMA                    E145,E170
# 8                          CGN/BER/CGN                          NaN
# 9                          DUS/BER/DUS                          NaN
# 10                         BWE/KLF/BWE                          NaN
# 11                         STR/BWE/STR                          NaN
# 12                 STR/BWE/POZ/BWE/STR                          NaN
# 13                         BCN/BWE/BCN                          NaN
# 14         BCN/TRN/BWE/BCN/BWE/TRN/BCN                          NaN
# 15                         BWE/POZ/BWE                          NaN
# 16                         PRG/BWE/PRG                          NaN
# 17                         BWE/POZ/BWE                          NaN
# 18                         CGN/AGA/CGN                         A319
# 19                         CGN/AGA/DUS                         A319
# 22                         VIE/DNK/VIE                         E145
# 23                         PAR/LAS/PAR                          NaN
# 24     SYR/DTW/LAS DFW/LAS/DTW LAS/DTW                     B737-800
# 25                         DTW/LAS/DTW                     B737-800
# 26                         CMF/LBG/CMF                          NaN
# 27                         DTW/LAS/DTW                     B737-800
# 28                         DTW/LAS/DTW                          NaN
# 29                         DTW/LAS/DTW                     B737-800
# 30                         DTW/LAS/DTW                     B737-800
# 31                         DTW/LAS/DTW                     B737-800
# 32                         DTW/LAS/DTW                          NaN
# 33                         DTW/LAS/DTW                          NaN
# ...                                ...                          ...
# 15407                      CGN/NUE/CGN               B737-800,FK100
# 15408                      CGN/NUE/CGN               B737-800,FK100
# 15409                      PAR/MLA/PAR                          NaN
# 15410                      MAD/TLV/MAD                          NaN
# 15411                      LIS/IBZ/LIS                          NaN
# 15412                  SDR/WAW KRK/SDR                          NaN
# 15413                          FRA/KEF                         A320
# 15414                      VIE/TIV/VIE  B737-700,E145ER,FK100,SF340
# 15415                      VIE/TGD/VIE  B737-700,E145ER,FK100,SF340
# 15416                      SZG/TIV/SZG  B737-700,E145ER,FK100,SF340
# 15417                      SZG/TIV/SZG  B737-700,E145ER,FK100,SF340
# 15418                      VIE/TIV/VIE  B737-700,E145ER,FK100,SF340
# 15419                      NCE/BOD/NCE                          NaN
# 15420                      VIE/FCO/VIE                A319,B737-800
# 15421                      VIE/FCO/VIE                A319,B737-800
# 15422                      LNZ/DBV/LNZ                     B737-800
# 15423                      DUS/FCO/DUS                     A320-200
# 15424                      ZRH/NCE/ZRH               B737-800,FK100
# 15425                      GVA/NCE/GVA               B737-800,FK100
# 15427                      FRA/KEF/FRA                     B737-700
# 15428                      FRA/KEF/FRA                     B737-700
# 15429                      PAR/SVQ/PAR                          NaN
# 15435                      VIE/OSD/VIE                     B737-800
# 15439                      XCR/VCE/XCR                          NaN
# 15441                      DUS/KGS/DUS                A319,B737-800
# 15442                      FRA/KGS/FRA                A319,B737-800
# 15443                      BOD/DUB/BOD                          NaN
# 15444                      MUC/AYT/MUC            A320-200,A321-200
# 15445                      MUC/AYT/MUC            A320-200,A321-200
# 15446                      VIE/MAD/VIE                        FK100
#
#        no of sectors  passengers  Total Flight Time (Dec)  \
# 0                  5         109                     4.24
# 2                  2         395                     3.50
# 3                  2         202                     3.84
# 4                  2          60                     1.84
# 6                  2          50                     1.00
# 7                  2          76                     1.00
# 8                  2           0                     0.00
# 9                  2           0                     0.00
# 10                 2           0                     0.00
# 11                 2           0                     0.00
# 12                 4           0                     0.00
# 13                 2           0                     0.00
# 14                 6           0                     0.00
# 15                 2           0                     0.00
# 16                 2           0                     0.00
# 17                 2           0                     0.00
# 18                 2         150                     7.34
# 19                 2         150                     7.34
# 22                 2          49                     4.50
# 23                 2           0                     0.00
# 24                 5         189                    12.24
# 25                 2         189                     8.41
# 26                 2           0                     0.00
# 27                 2         189                     8.16
# 28                 2           0                     0.00
# 29                 2          78                     8.16
# 30                 2          78                     8.16
# 31                 2          78                     8.16
# 32                 2           0                     0.00
# 33                 2           0                     0.00
# ...              ...         ...                      ...
# 15407              2         100                     1.66
# 15408              2         189                     1.50
# 15409              2           0                     0.00
# 15410              2           0                     0.00
# 15411              2           0                     0.00
# 15412              2           0                     0.00
# 15413              1         180                     3.33
# 15414              2         109                     2.66
# 15415              2         148                     2.50
# 15416              2          33                     3.66
# 15417              2          49                     2.84
# 15418              2         109                     2.66
# 15419              2           0                     0.00
# 15420              2         189                     2.84
# 15421              2         144                     2.75
# 15422              2         189                     2.66
# 15423              2         180                     3.50
# 15424              2         189                     2.00
# 15425              2         109                     1.50
# 15427              2           0                     0.00
# 15428              2         141                     7.00
# 15429              2           0                     0.00
# 15435              2         189                     5.16
# 15439              2           0                     0.00
# 15441              2         186                     6.66
# 15442              2         150                     6.00
# 15443              2           0                     0.00
# 15444              2         200                     5.50
# 15445              2         180                     5.66
# 15446              2         109                     7.00
#
#        Total Distance (NMi)     margin_y
# 0                   1075.07  2615.661430
# 2                   1354.40     0.000000
# 3                   1354.40     0.000000
# 4                    308.30  1786.800000
# 6                    201.52     0.000000
# 7                    201.52     0.000000
# 8                    506.28     0.000000
# 9                    515.88     0.000000
# 10                  1847.62     0.000000
# 11                   447.72     0.000000
# 12                   907.64     0.000000
# 13                  1491.46     0.000000
# 14                  3050.42     0.000000
# 15                   459.92     0.000000
# 16                   385.28     0.000000
# 17                   459.92     0.000000
# 18                  2875.82     0.000000
# 19                  2887.55     0.000000
# 22                  1468.72  5490.792364
# 23                  9443.40     0.000000
# 24                  4545.78    91.970773
# 25                  3030.52  2405.901139
# 26                   486.24     0.000000
# 27                  3030.52     0.000000
# 28                  3030.52     0.000000
# 29                  3030.52  2380.104459
# 30                  3030.52  2380.104459
# 31                  3030.52  2380.104459
# 32                  3030.52   666.934511
# 33                  3030.52   666.934511
# ...                     ...          ...
# 15407                342.80     0.000000
# 15408                342.80     0.000000
# 15409               1873.22     0.000000
# 15410               3824.56     0.000000
# 15411                981.44     0.000000
# 15412               2163.57     0.000000
# 15413               1294.85     0.000000
# 15414                709.16     0.000000
# 15415                725.42     0.000000
# 15416                776.84     0.000000
# 15417                776.84     0.000000
# 15418                709.16     0.000000
# 15419                695.56     0.000000
# 15420                839.30     0.000000
# 15421                839.30     0.000000
# 15422                760.68     0.000000
# 15423               1222.68     0.000000
# 15424                470.30     0.000000
# 15425                320.90     0.000000
# 15427               2589.70     0.000000
# 15428               2589.70     0.000000
# 15429               1536.12     0.000000
# 15435               1817.36     0.000000
# 15439                773.04     0.000000
# 15441               2453.88     0.000000
# 15442               2255.66     0.000000
# 15443               1118.96     0.000000
# 15444               2156.64     0.000000
# 15445               2156.64     0.000000
# 15446               1947.88     0.000000
#
# [9306 rows x 20 columns]

# %% [markdown]
# ## Assumptions based on data analysis
# - Correlating: we want to know how well does each feature correlate with ProfitMargin.We want to do this early in our project and match these quick correlations with modelled correlations later in the project.
# - Completing: We might need to complete the columns if it is necessary
# - Correlating:
#     1. A lot of features used 0 instead of NULL, but it will affect the model, we may need to fill the 0 with other number.
#     2. route code is relatively non-standard as it contains high ratio of duplicate (40%), so maybe dropped.
#     3. the combination of aircrafts need to be tranformed to another type of data.
# - Creating:
#     1. We may want to create a new feature called round trip based on route code to get the understanding of route
#     2. We may want to engineer the office country code to extract the country as a new feature
#     3. We may also want to create a discount range feature
#     4. Industry columns might have too many categories, and we may need to encode them in another format
# - Classifying: We may aslo add to our assumptions based on the problem description noted earlier.
#     1. Single trip (Round trip = 0) were more likely to have a better discount.
#     2. government were more likely to have a better discount./ sports may have a high limit on the budget.
#     3. The SA based country (country=Saudi Arabia) were more likely to have a better discount.

# %% [markdown]
# ### Creating new feature extracting from existing
# - 'Gross Margin'
# - 'Country'
# - 'Round_trip'

# %%
# cj = cj.rename(columns={'Margin_EnqNo_GBP_CALC':'gross', 'CostToClient_Total_GBP_CALC':'Cost'})

# %%
# def country_tranfrom(dataset):
#     country_mapping = {'IT':'Italy', 'FR':'France', 'DE':'Germany', 'UK':'United Kingdom',
#                        'AT':'Austria', 'US':'United States', 'CH':'Switzerland', 'MC':'Monaco',
#                        'TR':'Turkey', 'SE':'Sweden', 'AE':'United Arab Emirates', 'unknown': 'Other'}
#     dataset['Country'] = dataset['Office Country Code'].map(country_mapping)

# country_tranfrom(cj)

# %%
# cj = cj.dropna(subset=['Route code'])
# cj['Route code'] = cj['Route code'].map(lambda x:str(x))

# Route_code = list(cj['Route code'])
# round_trip = []
# for i in range(len(Route_code)):
#     if Route_code[i][:3] == Route_code[i][-3:]:
#         round_trip.append(1)
#     else:
#         round_trip.append(0)
# cj['Round_trip'] = round_trip

# %%
# cj.to_csv('CJ data.csv')

# %% [markdown]
# ## Visualize the missing-ness of data

# %%
cj = pd.read_excel(sampleFilePath, sep=',', header=0, quotechar='"', encoding='latin1')

# %%
cj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4491097e75d1> in <module>
# ----> 1 cj
#
# NameError: name 'cj' is not defined

# %%
cj.describe(include=['O'])

# %%
msno.matrix(cj.sample(500),
           figsize=(13,7),
           width_ratios=(15,1))
plt.savefig('msno.png', dpi=72)
plt.show()

# %%
tab_info = pd.DataFrame(cj.dtypes).T.rename(index={0:'column type'})
tab_info = tab_info.append(pd.DataFrame(cj.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info = tab_info.append(pd.DataFrame(cj.isnull().sum()/cj.shape[0]*100).T.
                         rename(index={0:'null values (%)'}))
display(tab_info)

# %% [markdown]
# ### Analyze by pivoting features
# To confirm some of our observations and assumptions, we can quickly analyze our feature correlations by pivoting features against each other.
# - **Country**: We observe significant average gross contribution from US (classifying#3).
# - **Round trip**: We confirm the observation during problem definition that Round trip = 0 had a better gross contribution(classifying#1).
# - **Industry**: The feature have a lot of categories. It may be best to derive a feature or a set of features from it.(creating#4)

# %%
cj[['Round_trip', 'gross']].groupby(['Round_trip'], as_index=False).mean().sort_values(by='margin', ascending=False)

# %%
cj[['Industry', 'gross']].groupby(['Industry'], as_index=False).sum().sort_values(by='gross', ascending=False).head()

# %% [markdown]
# ## Converting the solution goal to be categorical
# - check the plasma soup (Profit Margin correlation matrix)
# - fill up the Profit Margin col by using the correlation with other cols
# - exclude the outliers

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categ_col = cj.copy()
categ_col[['Industry', 'Country']] = categ_col[['Industry', 'Country']].apply(LabelEncoder().fit_transform)

# %% [markdown]
# ### Completing a numerical continuous feature
# We can consider three methods to complete a numerical continuous feature
# - A simple way is to generate random numbers between mean and standard deviation.
# - More accurate way of guessing missing values is to use other correlated features. In our case we note correlation among Age, Gender, and Pclass. Guess Age values using median values for Age across sets of Pclass and Gender feature combinations. So, median Age for Pclass=1 and Gender=0, Pclass=1 and Gender=1, and so on...
# - Combine methods 1 and 2. So instead of guessing null values based on median, use random numbers between mean and standard deviation, based on sets of Pclass and Gender combinations.

# %%
guess_features = np.zeros((2, 11))

# %%
def numerical_complete(colonne):
    for i in range(0, 2):
        for j in range(0, 11):
            guess_df = categ_col[(categ_col['Round_trip'] == i) & \
                                  (categ_col['Country'] == j)][colonne].dropna()

            col_guess = guess_df.median()

            guess_features[i,j] = round(col_guess, 2)

    for i in range(0, 2):
        for j in range(0, 11):
            categ_col.loc[ (categ_col[colonne].isnull()) & (categ_col.Round_trip == i) & (categ_col.Country == j),\
                    colonne] = guess_features[i,j]
            
    return categ_col[colonne]

cj['gross'] = numerical_complete(colonne = 'gross')
cj['Cost'] = numerical_complete(colonne = 'Cost')
cj['passengers'] = numerical_complete(colonne = 'passengers')
cj['Total Flight Time (Dec)'] = numerical_complete(colonne = 'Total Flight Time (Dec)')
cj['Total Distance (NMi)'] = numerical_complete(colonne = 'Total Distance (NMi)')

# %% [markdown]
# Now we could create the Profit Margin col since there is no null values in gross and cost cols, and then round them to 2 decimals.

# %%
cj['ProfitMargin(%)'] = round(cj['gross'] / cj['Cost'] * 100, 2)

# set the threshold for the dataset
cj = cj[(cj['ProfitMargin(%)'] > 0.5) & (cj['ProfitMargin(%)'] <= 50) &(cj['gross'] > 100) & (cj['gross'] < 50000)]
cj = cj[(cj['Product'] != 'Other') & (cj['Product'] != 'ACMI') & (cj['Product'] != 'Seat Sales') ]

# %%
cj[['Country', 'gross']].groupby(['Country'], as_index=False).mean().sort_values(by='gross', ascending=False)

# %%
cj['ProfitMargin(%)'].mean()

# %%
cj['gross'].sum()/67*12

# %%
single = cj['gross'][cj.Round_trip == 0]
Round = cj['gross'][cj.Round_trip == 1]
sinlge_median = single.median()
Round_median = Round.median()

plt.figure(figsize=(8,4))
sns.kdeplot(single, shade = False, color='royalblue',
             label = 'SingleTrip_gross')

sns.kdeplot(Round, shade = False, color='firebrick',
             label = 'RoundTrip_gross')

plt.axvline(sinlge_median, color='b',linestyle=":",alpha=0.8) 
plt.text(sinlge_median+3000,  0.00008,'SingleTrip_gross_median: %.1fpound' % (sinlge_median), color = 'b')

plt.axvline(Round_median, color='r',linestyle=":",alpha=0.8) 
plt.text(Round_median+3500,0.00006, 'RoundTrip_gross_median: %.1fpound' % (Round_median), color = 'r')

plt.title("Gross Profit of the Round/Single Trip", fontsize='large', fontweight='bold')
plt.xlabel('Gross Profit of the CJ and Tour Ops Department')
plt.savefig('output/triptype_gross.png', dpi=80)
plt.show()

# %%
cj.drop_duplicates(subset=['gross','Cost', 'ProfitMargin(%)', 'Flight date', 'Industry'], keep='first',inplace=True)

# %%
CJ = cj['gross'][cj.Product == 'CJ - Adhoc']
Tour_Ops = cj['gross'][cj.Product == 'Tour Ops']
CJ_median = CJ.median()
TourOps_median = Tour_Ops.median()

plt.figure(figsize=(8,4))
sns.distplot(CJ, hist = False, kde = True,
             kde_kws={"color": "royalblue", "lw": 1.5, 'linestyle':'-'},
             label = 'CJ_gross')

sns.distplot(Tour_Ops, hist = False, bins=6, kde = True,
             kde_kws={"color": "firebrick", "lw": 1.5, 'linestyle':'-'},
             label = 'TourOps_gross')

plt.axvline(CJ_median, color='b',linestyle=":",alpha=0.8) 
plt.text(CJ_median+3000,  0.0001,'CJ_gross_median: %.1fpound' % (CJ_median), color = 'b')

plt.axvline(TourOps_median, color='r',linestyle=":",alpha=0.8) 
plt.text(TourOps_median+4000,0.00006, 'TourOps_gross_median: %.1fpound' % (TourOps_median), color = 'r')

plt.title("Gross Profit of the CJ/TourOps Product", fontsize='large', fontweight='bold')
plt.xlabel('Gross Profit')
plt.savefig('output/department_gross.png', dpi=80)
plt.show()

# %% [markdown]
# ### Creating the Profit Margin(%) band

# %%
cj['ProfitMargin_band'] = pd.qcut(cj['ProfitMargin(%)'], 5)
cj['ProfitMargin_band'].unique()
# [(0.476, 5.434] < (5.434, 10.359] < (10.359, 15.283] < (15.283, 20.207] < (20.207, 25.131] < (25.131, 30.056] < (30.056, 34.98]]

# %%
def ProfitMargin_band(dataset):
    dataset.loc[ dataset['ProfitMargin(%)'] <= 2.5, 'ProfitMargin(%)'] = 0
    dataset.loc[(dataset['ProfitMargin(%)'] > 2.5) & (dataset['ProfitMargin(%)'] <= 5), 'ProfitMargin(%)'] = 1
    dataset.loc[(dataset['ProfitMargin(%)'] > 5) & (dataset['ProfitMargin(%)'] <= 8), 'ProfitMargin(%)'] = 2
    dataset.loc[(dataset['ProfitMargin(%)'] > 8) & (dataset['ProfitMargin(%)'] <= 13), 'ProfitMargin(%)'] = 3
    dataset.loc[ dataset['ProfitMargin(%)'] > 13, 'ProfitMargin(%)'] =4
    dataset['ProfitMargin(%)'] = dataset['ProfitMargin(%)'].astype(int)
    
ProfitMargin_band(cj)

# %%
len(cj)

# %%
g = sns.countplot(x="ProfitMargin(%)", data=cj, palette='Blues_d')
g.set_title("ProfitMargin Transactions Distribution")
total = len(cj)

for p in g.patches:
    height = p.get_height()
    g.text(p.get_x()+p.get_width()/2.,
            height + 30,
            '{:1.2f}%'.format(height/total*100),
            ha="center") 
    
sns.despine()

# %% [markdown]
# ### Analyze by visualizing data
# #### Correlating numerical features
# - start by understanding correlation between numerical features and our solution goal (ProfitMargin)
#
# **Observation**
# - Over 400 people flights have a high ProfitMargin rate (ProfitMargin(%) = 3)
# - Most flights carries 150 - 200 people
# - capacity with over 250 people flights have a high ProfitMargin rate
#
# **Decision**
#
# This simple analysis confirms our assumptions as decisions for subsequent workflow stages
# - we should consider passengers (correlating#1) in our model training
# - Complete the passengers feature for null values

# %%
import matplotlib.mlab as mlab
import seaborn as sns

# %%
g = sns.FacetGrid(cj, col='ProfitMargin(%)')
g.map(plt.hist, 'passengers', bins=50, alpha=0.8)
sns.despine()

# %% [markdown]
# #### Correlating numerical and ordinal features
# **Observations**
# - ProfitMargin(%) = 0 had most flights, and most chose to have a round trip. Confirming our classifying assumption #1.
# - high capacity aircrafts in ProfitMargin(%)=3 and ProfitMargin(%)=4 mostly chose to have a round trip.
#
# **Decision**
# - Consider Round_trip for model training

# %%
grid = sns.FacetGrid(cj, col='Round_trip', row='ProfitMargin(%)', aspect=1.6)
grid.map(plt.hist, 'passengers', alpha=0.8, bins=30)
grid.add_legend()
sns.despine()

# %% [markdown]
# ### Creating the passengers band
# - since the passengers have a lot null value and it is better to make this discrete data categorical.

# %%
cj['Passenger_band'] = pd.qcut(cj['passengers'], 4)
cj['Passenger_band'].unique()

# %%
def passenger_band(dataset):
    dataset.loc[ dataset['passengers'] <= 130, 'passengers'] = 0
    dataset.loc[(dataset['passengers'] > 130) & (dataset['passengers'] <= 170), 'passengers'] = 1
    dataset.loc[(dataset['passengers'] > 170) & (dataset['passengers'] <= 180), 'passengers'] = 2
    dataset.loc[ dataset['passengers'] > 180, 'passengers'] = 3
    dataset['passengers'] = dataset['passengers'].astype(int)
    
passenger_band(cj)

# %%
g = sns.countplot(x="passengers", data=cj, palette='Blues_d')
g.set_title("Passenger Number Distribution")
total = len(cj)

for p in g.patches:
    height = p.get_height()
    g.text(p.get_x()+p.get_width()/2.,
            height + 30,
            '{:1.2f}%'.format(height/total*100),
            ha="center") 
    
sns.despine()

# %% [markdown]
# ### Correcting by dropping features
# - Note that we need to split the data into train and test set for modeling

# %%
cj = cj.drop(['Enquiry No.', 'Job Status', 'industrycode', 'Office Country Code', 'ProfitMargin_band', 'Route code', 'Cost', 'Passenger_band'], axis=1)

# %% [markdown]
# ### Heatmap correlated with the solution goal

# %%
corrmat = cj.corr()

# %%
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'ProfitMargin(%)')['ProfitMargin(%)'].index
fig, ax = plt.subplots(figsize=(9, 7))

colormap = plt.cm.gist_earth
cm = np.corrcoef(cj[cols].values.T)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', 
                annot_kws={'size':10}, cmap=colormap, linecolor='white',
                 linewidths=0.1, vmax=1.0, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# #### Correlating categorical features
# Now we correlate categorical features with our solution goal.
#
# **Observations**
# - CJ product had much better ProfitMargin in switzerland if they were single trips and in US if they were round trips.
# - Exception in Seat Sales product had consideranle reward
# - ACMI had a flat fluctuation and kept a low rate
#
# **Decision**
# - Add Product and Country feature to model training

# %%
cj['Product'].unique()

# %%
g = sns.catplot(x="Country", y="ProfitMargin(%)",
                hue="Product", row="Round_trip",
                data=cj, kind="point",
                height=4, aspect=3, palette='ocean')
g.savefig('PrductProfitMargin.png')
sns.despine()

# %% [markdown]
# #### Correlating categorical and numerical features
# correlate categorical featuers (with non-numeric values) and numerical values.
#
# Consider correlating Product(Categorical), Round_trip(categorical), gross(Numeric continuous), with ProfitMargin(categorical)
#
# **Observations.**
# - Single trip contributes to the higher gross in general, expection in ACMI
# - The type of products correlates with gross.
#
# **Decisions.**
# - Consider scaled the numerical values

# %%
grid = sns.FacetGrid(cj, row='Round_trip', col='Product')
grid.map(sns.barplot, 'ProfitMargin(%)', 'gross', alpha=0.8, ci=None)
grid.add_legend()
sns.despine()

# %% [markdown]
# ### Canceling Orders
# - I count the number of transactions corresponding the canceled orders

# %%
# cancel = df_cj[df_cj['Job Status'] == 'Cancelled']
# temp = cancel.groupby(by=['ownerid', 'Industry'], as_index=False)['Contactid'].count()

# nb_cancels_per_op = temp.rename(columns = {'Contactid':'Number of flights'})
# nb_cancels_per_op.sort_values('Number of flights', ascending=False).head(5)

# %%
temp = cj.groupby(by=['ownerid', 'Industry'], as_index=False)['companyid'].count()

nb_flights_per_op = temp.rename(columns = {'companyid':'Number of flights'})
nb_flights_per_op.sort_values('Number of flights', ascending=False).head(5)

# %% [markdown]
# The first lines of this list shows several things worthy of interest:
# - n.196 operator has dealed 2955 order since 2014, and he has connected a strong relationship with Tour Operators
# - the business with tour operators and aircraft operator has a strong vitality
# - the existence of operators who only has just taken off his career in sales (n.136)

# %%
cj.to_csv('CJ filtered.csv', index=0)
